# %%
import pandas as pd
import pyreadstat

# %%
df, meta = pyreadstat.read_sav("gastos_tabla.sav")
df.head()
# Out:
#    ANOENC  NUMERO CODIGO       GASTO  PORCEN    CANTIDAD     GASTMON  \
# 0  2006.0     1.0  01112  29415522.0     0.0  10354264.0  29415522.0
# 1  2006.0     1.0  01114   2494436.0     0.0    705973.0   2494436.0
# 2  2006.0     1.0  01115  57113177.0     0.0         NaN  57113177.0
# 3  2006.0     1.0  01117   6000766.0     0.0         NaN   6000766.0
# 4  2006.0     1.0  01121  27085813.0     0.0   1882593.0  27085813.0
#
#    GASTNOM1  GASTNOM2  GASTNOM3  GASTNOM4  GASTNOM5       NACTOR
# 0       NaN       NaN       NaN       NaN       NaN  902614262.0
# 1       NaN       NaN       NaN       NaN       NaN  902614262.0
# 2       NaN       NaN       NaN       NaN       NaN  902614262.0
# 3       NaN       NaN       NaN       NaN       NaN  902614262.0
# 4       NaN       NaN       NaN       NaN       NaN  902614262.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1677656 entries, 0 to 1677655
# Data columns (total 13 columns):
# ANOENC      1677656 non-null float64
# NUMERO      1677656 non-null float64
# CODIGO      1677656 non-null object
# GASTO       1677656 non-null float64
# PORCEN      1677656 non-null float64
# CANTIDAD    659136 non-null float64
# GASTMON     1677655 non-null float64
# GASTNOM1    5812 non-null float64
# GASTNOM2    2563 non-null float64
# GASTNOM3    1439 non-null float64
# GASTNOM4    19950 non-null float64
# GASTNOM5    10 non-null float64
# NACTOR      1677656 non-null float64
# dtypes: float64(12), object(1)
# memory usage: 166.4+ MB

# %%
df.columns
# Out:
# Index(['ANOENC', 'NUMERO', 'CODIGO', 'GASTO', 'PORCEN', 'CANTIDAD', 'GASTMON',
#        'GASTNOM1', 'GASTNOM2', 'GASTNOM3', 'GASTNOM4', 'GASTNOM5', 'NACTOR'],
#       dtype='object')

# %%
df = df.apply(lambda x: x/100 if x.name in ['GASTO', 'PORCEN', 'CANTIDAD', 'GASTMON',
                                       'GASTNOM1', 'GASTNOM2', 'GASTNOM3', 'GASTNOM4', 'GASTNOM5'] else x)
df = df.apply(lambda x: x.astype(int) if x.name in ['ANOENC', 'NUMERO'] else x)
df = df.apply(lambda x: x/1000000 if x.name in ['NACTOR'] else x)

# %%
df.head()
# Out:
#    ANOENC  NUMERO CODIGO      GASTO  PORCEN   CANTIDAD    GASTMON  GASTNOM1  \
# 0    2006       1  01112  294155.22     0.0  103542.64  294155.22       NaN
# 1    2006       1  01114   24944.36     0.0    7059.73   24944.36       NaN
# 2    2006       1  01115  571131.77     0.0        NaN  571131.77       NaN
# 3    2006       1  01117   60007.66     0.0        NaN   60007.66       NaN
# 4    2006       1  01121  270858.13     0.0   18825.93  270858.13       NaN
#
#    GASTNOM2  GASTNOM3  GASTNOM4  GASTNOM5      NACTOR
# 0       NaN       NaN       NaN       NaN  902.614262
# 1       NaN       NaN       NaN       NaN  902.614262
# 2       NaN       NaN       NaN       NaN  902.614262
# 3       NaN       NaN       NaN       NaN  902.614262
# 4       NaN       NaN       NaN       NaN  902.614262

# %%
#Además de los decimales, del word, saca los valores que sirven la checkear que la carga es correcta
#Automatizando eso en una función, if True, then print('los datos están bien')
#Pide a Laura que te pase las tablas dinámicas
#INtenta construir una serie temporal para análisis
#Reproduce los análisis que han hecho en el WORD del estudio

# %%
## HOGAR

ruta = "/home/fserrey/gitrep/ACA_project/docs_table/hogar_tablas"
file_path = ruta+'/hogar_tabla_2006.sav'
df, meta = pyreadstat.read_sav(file_path)

# %%
df.head(2)
# Out:
#   ANOENC NUMERO CCAA NUTS1 CAPROV TAMAMU DENSI CLAVE CLATEO       NACTOR  ...  \
# 0   2006  00001   09     5      6      2     1     1      2  902614262.0  ...
# 1   2006  00002   14     6      6      4     2     1      2  256638442.0  ...
#
#    IMPEXAC IMPUEXAC  INTERIN  IMPU_INTER  NUMPERI  COMIMH  COMISD  COMIHU  \
# 0   5020.0        1       08           6      2.0    56.0     0.0     0.0
# 1   2102.0        1       05           6      2.0   112.0     0.0     0.0
#
#    COMIINV  COMITOT
# 0      2.0     58.0
# 1      0.0    112.0
#
# [2 rows x 174 columns]

# %%
str(df.loc[0, "ANOENC"])#[0])
# Out:
# '2006'

# %%
df = df.apply(lambda x: x.astype(float)/100 if x.name not in ['ANOENC', 'NUMERO','CODIGO', 'NACTOR'] else x)
df = df.apply(lambda x: x.astype(int) if x.name in ['ANOENC', 'NUMERO'] else x)
df = df.apply(lambda x: x/1000000 if x.name in ['NACTOR'] else x)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1677656 entries, 0 to 1677655
# Data columns (total 13 columns):
# ANOENC      1677656 non-null int64
# NUMERO      1677656 non-null int64
# CODIGO      1677656 non-null object
# GASTO       1677656 non-null float64
# PORCEN      1677656 non-null float64
# CANTIDAD    659136 non-null float64
# GASTMON     1677655 non-null float64
# GASTNOM1    5812 non-null float64
# GASTNOM2    2563 non-null float64
# GASTNOM3    1439 non-null float64
# GASTNOM4    19950 non-null float64
# GASTNOM5    10 non-null float64
# NACTOR      1677656 non-null float64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 166.4+ MB

# %%
df.head(2)
# Out:
#    ANOENC  NUMERO CODIGO      GASTO  PORCEN   CANTIDAD    GASTMON  GASTNOM1  \
# 0    2006       1  01112  294155.22     0.0  103542.64  294155.22       NaN
# 1    2006       1  01114   24944.36     0.0    7059.73   24944.36       NaN
#
#    GASTNOM2  GASTNOM3  GASTNOM4  GASTNOM5      NACTOR
# 0       NaN       NaN       NaN       NaN  902.614262
# 1       NaN       NaN       NaN       NaN  902.614262

# %%
# Out:
# '2006'
